# %%
#Python获取股票数据和可视化
#https://zhuanlan.zhihu.com/p/54299970

#利用深度学习和机器学习预测股票市场
#https://www.jiqizhixin.com/articles/2019-01-04-16

#用 LSTM 做时间序列预测的一个小例子
#https://cloud.tencent.com/developer/article/1083338

#sequence to vector的LSTM方法预测
#https://blog.csdn.net/hzy459176895/article/details/90512104

#NLP量化交易：基于财务报表的情绪分析（附代码）
#https://cloud.tencent.com/developer/article/1594073

# %%
# 导入包
import pandas as pd
import numpy as np

# 在notebook内绘图
import matplotlib.pyplot as plt
# %matplotlib inline

# 设置图形大小
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = 20, 10

# %%
# 导入所需的库
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM
# Out:
# Using TensorFlow backend.

# %%
import tushare as ts

from pylab import mpl
mpl.rcParams['font.sans-serif']=['SimHei']
mpl.rcParams['axes.unicode_minus']=False

#设置token
token='######################'
#ts.set_token(token)
pro = ts.pro_api(token)

# %%
#获取当前上市的股票代码、简称、注册地、行业、上市时间等数据
basic=pro.stock_basic(list_status='L')
#查看前五行数据
basic.head(5)
# Out:
#      ts_code  symbol  name area industry market list_date
# 0  000001.SZ  000001  平安银行   深圳       银行     主板  19910403
# 1  000002.SZ  000002   万科A   深圳     全国地产     主板  19910129
# 2  000004.SZ  000004  国农科技   深圳     生物制药     主板  19910114
# 3  000005.SZ  000005  世纪星源   深圳     环境保护     主板  19901210
# 4  000006.SZ  000006  深振业A   深圳     区域地产     主板  19920427

# %%
#获取贵州茅台(600519)日行情数据
row=pro.daily(ts_code='600519.SH', start_date='20160101',
               end_date='20200403')
row.head()
# Out:
#      ts_code trade_date     open     high      low    close  pre_close  \
# 0  600519.SH   20200403  1139.03  1147.96  1131.98  1139.79     1145.0
# 1  600519.SH   20200402  1104.00  1145.00  1103.88  1145.00     1103.0
# 2  600519.SH   20200401  1117.00  1129.00  1103.00  1103.00     1111.0
# 3  600519.SH   20200331  1082.00  1115.00  1081.80  1111.00     1072.0
# 4  600519.SH   20200330  1060.25  1077.00  1057.00  1072.00     1075.5
#
#    change  pct_chg       vol       amount
# 0   -5.21  -0.4550  27617.61  3148421.866
# 1   42.00   3.8078  45205.61  5095167.594
# 2   -8.00  -0.7201  33205.35  3700184.247
# 3   39.00   3.6381  47984.37  5293170.703
# 4   -3.50  -0.3254  30687.41  3279823.025

# %%
pa=row.copy()

pa.loc["1036"] = ["","20200406","","","",0,"","","","",""]
pa.loc["1037"] = ["","20200407","","","",0,"","","","",""]
pa.loc["1038"] = ["","20200408","","","",0,"","","","",""]
pa.loc["1039"] = ["","20200409","","","",0,"","","","",""]
pa.loc["1040"] = ["","20200410","","","",0,"","","","",""]

#save datetime series as datetime formart
pa["datetime"]=pd.to_datetime(pa.trade_date)
pa.sort_values('datetime', inplace=True)
#set datetime series as index
pa=pa.set_index('datetime')
ts=pa.close

pa
# Out:
#               ts_code trade_date     open     high      low    close  \
# datetime
# 2016-02-19    201.71    1.4    0.69  14238.5       287756
# ...              ...    ...     ...      ...          ...
# 2020-03-02      1057  29.01  2.7446    47663  5.15433e+06
# 2020-03-03   1086.01  26.99  2.4852  50250.2  5.58523e+06
# 2020-03-04      1113  15.92  1.4304    53793  6.08015e+06
# 2020-03-05   1128.92  42.08  3.7275  62426.4  7.21049e+06
# 2020-03-06      1171  -15.5 -1.3237    30641  3.55362e+06
# 2020-03-09    1155.5 -41.49 -3.5907  43404.1  4.86529e+06
# 2020-03-10   1114.01  41.99  3.7693  58062.9  6.63594e+06
# 2020-03-11      1156   2.52   0.218  35547.6  4.12461e+06
# 2020-03-12   1158.52 -20.02 -1.7281  36630.6  4.17261e+06
# 2020-03-13    1138.5 -26.47  -2.325  75885.3   8.3485e+06
# 2020-03-16   1112.03 -45.03 -4.0494  51232.5  5.54895e+06
# 2020-03-17      1067  -21.9 -2.0525  79359.1  8.27747e+06
# 2020-03-18    1045.1 -37.11 -3.5509  73459.9  7.58276e+06
# 2020-03-19   1007.99 -11.99 -1.1895   102265  1.00759e+07
# 2020-03-20       996  39.28  3.9438  60139.2  6.16909e+06
# 2020-03-23   1035.28 -16.28 -1.5725  48472.1  4.91812e+06
# 2020-03-24      1019     37   3.631    46651  4.90036e+06
# 2020-03-25      1056   24.1  2.2822  37048.7  4.01506e+06
# 2020-03-26    1080.1 -15.18 -1.4054  30048.6  3.23175e+06
# 2020-03-27   1064.92  10.58  0.9935  36261.1  3.93176e+06
# 2020-03-30    1075.5   -3.5 -0.3254  30687.4  3.27982e+06
# 2020-03-31      1072     39  3.6381  47984.4  5.29317e+06
# 2020-04-01      1111     -8 -0.7201  33205.3  3.70018e+06
# 2020-04-02      1103     42  3.8078  45205.6  5.09517e+06
# 2020-04-03      1145  -5.21  -0.455  27617.6  3.14842e+06
# 2020-04-06
# 2020-04-07
# 2020-04-08
# 2020-04-09
# 2020-04-10
#
# [1041 rows x 11 columns]

# %%
memory=120  #使用过去n个数据来预测下一个数据
train_end="2019-03-31 00:00:00"
valid_start="2019-04-01 00:00:00"

# 创建数据框
new_data=ts.to_frame()

# 创建训练集和验证集

dataset = new_data.values
train = new_data[:train_end].values
valid = new_data[valid_start:].values

# 将数据集转换为x_train和y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

x_train, y_train = [], []
for i in range(memory,len(train)):
    x_train.append(scaled_data[i-memory:i,0])
    y_train.append(scaled_data[i,0])
x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0],x_train.shape[1],1))

# 创建和拟合LSTM网络
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(units=50))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(x_train, y_train, epochs=20, batch_size=1, verbose=2)

# 使用过去值来预测
inputs = new_data[len(new_data) - len(valid) - memory:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(memory,inputs.shape[0]):
    X_test.append(inputs[i-memory:i,0])
X_test = np.array(X_test)

X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
# Out:
# Epoch 1/20
#  - 50s - loss: 0.0020
# Epoch 2/20
#  - 54s - loss: 6.6526e-04
# Epoch 3/20
#  - 52s - loss: 5.1577e-04
# Epoch 4/20
#  - 60s - loss: 4.6744e-04
# Epoch 5/20
#  - 62s - loss: 3.8490e-04
# Epoch 6/20
#  - 59s - loss: 3.3163e-04
# Epoch 7/20
#  - 59s - loss: 2.5199e-04
# Epoch 8/20
#  - 57s - loss: 2.3746e-04
# Epoch 9/20
#  - 60s - loss: 2.1774e-04
# Epoch 10/20
#  - 57s - loss: 2.2313e-04
# Epoch 11/20
#  - 56s - loss: 2.1184e-04
# Epoch 12/20
#  - 52s - loss: 2.2812e-04
# Epoch 13/20
#  - 49s - loss: 1.9875e-04
# Epoch 14/20
#  - 53s - loss: 2.1374e-04
# Epoch 15/20
#  - 56s - loss: 1.9380e-04
# Epoch 16/20
#  - 54s - loss: 2.0969e-04
# Epoch 17/20
#  - 54s - loss: 1.7158e-04
# Epoch 18/20
#  - 54s - loss: 1.9372e-04
# Epoch 19/20
#  - 55s - loss: 2.2309e-04
# Epoch 20/20
#  - 52s - loss: 1.7067e-04

# %%
# 在notebook内绘图
import matplotlib.pyplot as plt
# %matplotlib inline

# 设置图形大小
from matplotlib.pylab import rcParams
rcParams['figure.figsize'] = 20,10

# 用于绘图
train = new_data[:train_end]
valid = new_data[valid_start:]
valid['Predictions'] = closing_price
plt.plot(train.close)
plt.plot(valid[['close','Predictions']])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# [<matplotlib.lines.Line2D at 0x2011dd5fb70>,
#  <matplotlib.lines.Line2D at 0x20118664128>]

# %%
t,p=valid["2019-9":"2019-11"]['close'],valid["2019-9":"2019-11"]['Predictions']

#RMSE
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(t, p))
rmse=round(rmse,2)
print("RMSE",rmse)

#MAPE
import numpy as np
mape=np.mean(np.abs((p - t) / t)) * 100
mape=round(mape,2)
print("MAPE",mape)
# Out:
# RMSE 42.52
# MAPE 3.32

# %%
a,f=812,812
c,d=[],[]
for idx,row in valid.iterrows():
    b=row.Predictions
    r=row.close
    c.append(round((b/a-1)*100,3))
    d.append(round((r/f-1)*100,3))
    a=b
    f=r
valid2=valid.copy()
valid2["増減（実際）"]=d
valid2["増減"]=c
valid2
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in double_scalars
#   import sys
#               close  Predictions   増減（実際）      増減
# datetime
# 2019-04-01   859.00   859.089600    5.788   5.799
# 2019-04-02   850.00   858.466064   -1.048  -0.073
# 2019-04-03   844.50   848.151123   -0.647  -1.202
# 2019-04-04   865.00   844.171326    2.427  -0.469
# 2019-04-08   900.20   866.402832    4.069   2.634
# 2019-04-09   905.00   900.275696    0.533   3.910
# 2019-04-10   947.99   901.048035    4.750   0.086
# 2019-04-11   925.20   943.865356   -2.404   4.752
# 2019-04-12   914.00   915.309692   -1.211  -3.025
# 2019-04-15   907.00   908.429321   -0.766  -0.752
# 2019-04-16   939.90   904.432922    3.627  -0.440
# 2019-04-17   952.00   939.766602    1.287   3.907
# 2019-04-18   945.50   947.398804   -0.683   0.812
# 2019-04-19   952.56   939.082520    0.747  -0.878
# 2019-04-22   949.20   947.470398   -0.353   0.893
# 2019-04-23   974.95   943.107788    2.713  -0.460
# 2019-04-24   970.00   969.828552   -0.508   2.833
# 2019-04-25   952.37   960.516052   -1.818  -0.960
# 2019-04-26   945.00   943.959351   -0.774  -1.724
# 2019-04-29   971.97   939.947144    2.854  -0.425
# 2019-04-30   974.00   968.646667    0.209   3.053
# 2019-05-06   906.00   965.938171   -6.982  -0.280
# 2019-05-07   890.00   897.167603   -1.766  -7.120
# 2019-05-08   884.40   892.613953   -0.629  -0.508
# 2019-05-09   858.81   889.554871   -2.893  -0.343
# 2019-05-10   907.12   864.211304    5.625  -2.849
# 2019-05-13   892.00   915.672668   -1.667   5.955
# 2019-05-14   886.57   892.138367   -0.609  -2.570
# 2019-05-15   927.00   887.144897    4.560  -0.560
# 2019-05-16   929.91   927.494812    0.314   4.548
# ...             ...          ...      ...     ...
# 2020-03-02  1086.01  1033.863647    2.745  -3.175
# 2020-03-03  1113.00  1069.919312    2.485   3.487
# 2020-03-04  1128.92  1089.002197    1.430   1.784
# 2020-03-05  1171.00  1098.721436    3.727   0.892
# 2020-03-06  1155.50  1136.891724   -1.324   3.474
# 2020-03-09  1114.01  1111.571045   -3.591  -2.227
# 2020-03-10  1156.00  1076.149780    3.769  -3.187
# 2020-03-11  1158.52  1128.612305    0.218   4.875
# 2020-03-12  1138.50  1120.273193   -1.728  -0.739
# 2020-03-13  1112.03  1102.058960   -2.325  -1.626
# 2020-03-16  1067.00  1081.151855   -4.049  -1.897
# 2020-03-17  1045.10  1042.351440   -2.052  -3.589
# 2020-03-18  1007.99  1030.630859   -3.551  -1.124
# 2020-03-19   996.00   996.877625   -1.189  -3.275
# 2020-03-20  1035.28   991.752808    3.944  -0.514
# 2020-03-23  1019.00  1031.902466   -1.573   4.048
# 2020-03-24  1056.00  1005.012878    3.631  -2.606
# 2020-03-25  1080.10  1044.236084    2.282   3.903
# 2020-03-26  1064.92  1058.500977   -1.405   1.366
# 2020-03-27  1075.50  1037.693237    0.994  -1.966
# 2020-03-30  1072.00  1051.768555   -0.325   1.356
# 2020-03-31  1111.00  1046.015015    3.638  -0.547
# 2020-04-01  1103.00  1086.748657   -0.720   3.894
# 2020-04-02  1145.00  1070.543701    3.808  -1.491
# 2020-04-03  1139.79  1116.002197   -0.455   4.246
# 2020-04-06     0.00  1101.225220 -100.000  -1.324
# 2020-04-07     0.00   110.389778      NaN -89.976
# 2020-04-08     0.00   161.027817      NaN  45.872
# 2020-04-09     0.00   151.122040      NaN  -6.152
# 2020-04-10     0.00   135.286835      NaN -10.478
#
# [252 rows x 4 columns]

# %%
t,p=pd.Series(d[:-5]),pd.Series(c[:-5])

#RMSE
from sklearn.metrics import mean_squared_error
rmse=np.sqrt(mean_squared_error(t, p))
rmse=round(rmse,2)
print("RMSE",rmse)
# Out:
# RMSE 2.86
